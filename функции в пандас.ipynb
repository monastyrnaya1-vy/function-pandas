# %%
#Задание 1**
#Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
#- оценка 2 и меньше - низкий рейтинг
#- оценка 4 и меньше - средний рейтинг
#- оценка 4.5 и 5 - высокий рейтинг

#Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
df = pd.read_csv('ratings.csv')
df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
# userId       100004 non-null int64
# movieId      100004 non-null int64
# rating       100004 non-null float64
# timestamp    100004 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
def ratings (param):
    if param >= 4.5:
        return "высокий рейтинг" 
    elif param < 4.5 and param > 2:
        return "средний рейтинг"
    elif param <= 2:
        return "низкий рейтинг"
    return

# %%
df['class'] = df['rating'].apply(ratings)

# %%
df.head(50)
# Out:
#     userId  movieId  rating   timestamp            class
# 0        1       31     2.5  1260759144  средний рейтинг
# 1        1     1029     3.0  1260759179  средний рейтинг
# 2        1     1061     3.0  1260759182  средний рейтинг
# 3        1     1129     2.0  1260759185   низкий рейтинг
# 4        1     1172     4.0  1260759205  средний рейтинг
# 5        1     1263     2.0  1260759151   низкий рейтинг
# 6        1     1287     2.0  1260759187   низкий рейтинг
# 7        1     1293     2.0  1260759148   низкий рейтинг
# 8        1     1339     3.5  1260759125  средний рейтинг
# 9        1     1343     2.0  1260759131   низкий рейтинг
# 10       1     1371     2.5  1260759135  средний рейтинг
# 11       1     1405     1.0  1260759203   низкий рейтинг
# 12       1     1953     4.0  1260759191  средний рейтинг
# 13       1     2105     4.0  1260759139  средний рейтинг
# 14       1     2150     3.0  1260759194  средний рейтинг
# ...

# %%
#Задание 2
#Используем файл keywords.csv.
#Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. 
#Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. 
#Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#geo_data = {
#'Центр': ['москва', 'тула', 'ярославль'],
#'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
#}
#Результат классификации запишите в отдельный столбец region.

# %%
key = pd.read_csv('keywords.csv')
key.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
geo_data = {'Центр': ['москва', 'тула', 'ярославль'], 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']}

# %%
def geo (row):
    for i, v in geo_data.items():
        for el in v:
            if row == el:
                return i     
    return 'undefined'

# %%
key['region'] = key['keyword'].apply(geo)

# %%
key.head(200)
# Out:
#              keyword     shows     region
# 0                 вк  64292779  undefined
# 1      одноклассники  63810309  undefined
# 2              порно  41747114  undefined
# 3               ютуб  39995567  undefined
# 4          вконтакте  21014195  undefined
# ..               ...       ...        ...
# 195          торрент    716336  undefined
# 196   порно рассказы    729707  undefined
# 197  погода в москве    745745  undefined
# 198         слизарио    715083  undefined
# 199               е1    705533  undefined
#
# [200 rows x 3 columns]

# %%
#Вопрос:как теперь сгруппировать по новому столбцу ('region') и записать кол-во в отдельный столбец?
key1 = key.groupby('region').count (). reset_index. head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ecf980b93b6e> in <module>
#       1 #Вопрос:как теперь сгруппировать по новому столбцу ('region') и записать кол-во в отдельный столбец?
# ----> 2 key1 = key.groupby('region').count (). reset_index. head()
#
# AttributeError: 'function' object has no attribute 'head'

# %% [markdown]
# Задание 3 (бонусное)
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#
# для каждой строки пройдите по всем годам списка years
# если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга

# %%
import numpy as np

# %%
films = pd.read_csv('ratings.csv')

# %%
films.head()

# %%
import datetime

# %%
def data (row):
    timestamp = datetime.datetime.fromtimestamp(row)
    return timestamp.strftime('%Y-%m-%d')

# %%
films['date'] = films['timestamp'].apply(data)

# %%
films.head()

# %%
years = str(np.arange(1950, 2011))

# %%
for i in years.split():
    print(i)
# Out:
# [1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010]

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()

# %%
movies1 = movies.merge(films)

# %%
movies1.head()

# %%
def word (row):
    row = row.replace('(', '')
    row = row.replace(')', '')
    return row

# %%
movies1['word'] = movies1['title'].apply(word)
movies1.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp        date            word
# 0       7     3.0   851866703  1996-12-29  Toy Story 1995
# 1       9     4.0   938629179  1999-09-29  Toy Story 1995
# 2      13     5.0  1331380058  2012-03-10  Toy Story 1995
# 3      15     2.0   997938310  2001-08-16  Toy Story 1995
# 4      19     3.0   855190091  1997-02-06  Toy Story 1995

# %%
def production_year (param):
    for i in years.split():
        if i in param:
            return i
    return '1900'

# %%
movies1['year'] = movies1['word'].apply(production_year)

# %%
movies1.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp        date            word  year
# 0       7     3.0   851866703  1996-12-29  Toy Story 1995  1995
# 1       9     4.0   938629179  1999-09-29  Toy Story 1995  1995
# 2      13     5.0  1331380058  2012-03-10  Toy Story 1995  1995
# 3      15     2.0   997938310  2001-08-16  Toy Story 1995  1995
# 4      19     3.0   855190091  1997-02-06  Toy Story 1995  1995

# %%
movies1.groupby('year').agg('mean')['rating'].sort_values(ascending=False).head()
# Out:
# year
# 1957    4.067797
# 1952    4.061538
# 1954    4.044343
# 1972    4.029621
# 1974    4.001934
# Name: rating, dtype: float64
